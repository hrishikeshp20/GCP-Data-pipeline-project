# %% [markdown]
# # Tools and technologies used in this project-
#  ## 1. Cloud - Google
#  ## 2. Astro CLI
#  ## 3. Docker
#  ## 4. Airflow

# %% [markdown]
# #  --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## PIPELINE
# ![Untitled design.png](attachment:d45cc51c-05a6-4791-80e7-28861fc900b3.png)
#
#
# # Zoomed In - 1
# ![Screenshot 2024-02-04 092208.png](attachment:d0ff17a9-d026-4dd3-9be3-27f77cc4df77.png)
#
# # Zoomed In - 2
# ![Screenshot 2024-02-04 092337.png](attachment:5c3355d6-4977-4e8e-8c22-b3895551ffc1.png)

# %% [markdown]
# #  --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Visualisation and Dashboard
# ![Screenshot 2024-02-04 092524.png](attachment:a8b1f1c2-a672-4c29-ae56-8abc3d67aa4b.png)

# %% [markdown]
# #  --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Breakdown of project Files
#
# ## 1. Dag File
# Logic and flow of Data Pipeline is written and executed here.
# ![Screenshot 2024-02-04 093625.png](attachment:0eb93037-6289-46a5-9e68-1d3b2a644631.png)
#
#
# ## 2. Transformation and Data-modelling File
# All SQL queries related to transformation and data-modelling are stored here
# ![Screenshot 2024-02-04 094236.png](attachment:e6556620-d42f-41bc-b74f-67568f09d633.png)
#
#
# ## 3. Dataset Source file
# Dataset CSV is stored here
# ![Screenshot 2024-02-04 093701.png](attachment:5c04dce3-967c-4a84-95e6-742a5c4fb0ef.png)
